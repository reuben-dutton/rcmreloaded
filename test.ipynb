# %%
from pipeline.pipeline import Pipeline
from pipeline.enums import (
    Palette,
    Theme,
    Frame,
)

# %%
p = (
        Pipeline()
        .filter(Theme.DEFAULT)
        .palette(Palette.DEFAULT)
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 p = (
#       2         Pipeline()
# ----> 3         .filter(Theme.load("sunset"))
#       4         .palette(Palette.DEFAULT)
#       5 )
#
# File m:\dev\rcmreloaded\pipeline\enums.py:52, in Theme.load(tag)
#      49 @staticmethod
#      50 def load(tag) -> KDETheme:
#      51     with open(config.THEME_DIRECTORY / f'{tag}.rcmt', 'rb') as f:
# ---> 52         return KDETheme.deserialize(f.read())
#
# File m:\dev\rcmreloaded\pipeline\themes.py:108, in KDETheme.deserialize(cls, data)
#     106 @classmethod
#     107 def deserialize(cls, data: bytes) -> "KDETheme":
# --> 108     return pickle.loads(data)
#
# ModuleNotFoundError: No module named 'models.themes'

# %%
p.generate()
# Out:
# <PIL.Image.Image image mode=RGBA size=1200x1200>
